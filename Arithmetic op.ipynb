# %% [markdown]
# <a href="https://colab.research.google.com/github/parthpanaskar96-svg/PL2/blob/main/Arithmetic%20op.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PYTHON

# %%
a,b=int(input("Enter number a:")),int(input("Enter number b:"))
print("a+b=",a+b)
print("a-b=",a-b)
print("aXb=",a*b)
print("a/b",a/b)
# Out:
# Enter number a:21
# Enter number b:54
# a+b= 75
# a-b= -33
# aXb= 1134
# a/b 0.3888888888888889
