# %% [markdown]
# <a href="https://colab.research.google.com/github/parthpanaskar96-svg/PL2/blob/main/Personal_biodata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python
# Day converter into year , month and weeks

# %%
name = "Parth Shivaji Panaskar"
age = 20
occupation = "IT Engineer"
city = "Vaduj"
email = "parthpanaskar96@gmail.com"
height=180
weight=72


print("--- Personal Biodata ---")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Occupation: {occupation}")
print(f"City: {city}")
print(f"Email: {email}")
print(f"Height: {height} cm")
print(f"Weight: {weight} kg")
print("------------------------")
# Out:
# --- Personal Biodata ---
# Name: Parth Shivaji Panaskar
# Age: 20
# Occupation: IT Engineer
# City: Vaduj
# Email: parthpanaskar96@gmail.com
# Height: 180 cm
# Weight: 72 kg
# ------------------------
