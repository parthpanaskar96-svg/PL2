# %% [markdown]
# <a href="https://colab.research.google.com/github/parthpanaskar96-svg/PL2/blob/main/Function_lambda_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PYTHON

# %%
# Lambda function examples

# Basic lambda
square   = lambda x: x ** 2
cube     = lambda x: x ** 3
add      = lambda a, b: a + b

print('Square of 5  :', square(5))
print('Cube of 3    :', cube(3))
print('Add 4 + 6    :', add(4, 6))

# Lambda with map, filter, sorted
nums = [1, 2, 3, 4, 5, 6]
squares  = list(map(lambda x: x**2, nums))
evens    = list(filter(lambda x: x % 2 == 0, nums))

students = [('Aditya', 85), ('Bhau', 92), ('Parth', 78)]
by_marks = sorted(students, key=lambda s: s[1], reverse=True)

print('Squares :', squares)
print('Evens   :', evens)
print('Ranked  :', by_marks)
# Out:
# Square of 5  : 25
# Cube of 3    : 27
# Add 4 + 6    : 10
# Squares : [1, 4, 9, 16, 25, 36]
# Evens   : [2, 4, 6]
# Ranked  : [('Bhau', 92), ('Aditya', 85), ('Parth', 78)]
