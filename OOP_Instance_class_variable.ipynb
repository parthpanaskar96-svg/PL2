# %% [markdown]
# <a href="https://colab.research.google.com/github/parthpanaskar96-svg/PL2/blob/main/OOP_Instance_class_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PYTHON

# %%
class Employee:
    # Class variable (shared by all objects)
    company_name = "TechCorp"
    employee_count = 0

    def __init__(self, name, salary):
        # Instance variables (unique to each object)
        self.name = name
        self.salary = salary
        Employee.employee_count += 1

    def display(self):
        print(f"Name: {self.name}, Salary: {self.salary}")
        print(f"Company: {Employee.company_name}")

e1 = Employee("Alice", 50000)
e2 = Employee("Bob", 60000)

e1.display()
e2.display()

print(f"\nTotal Employees: {Employee.employee_count}")
print(f"Company (via class): {Employee.company_name}")
print(f"Company (via object): {e1.company_name}")
# Out:
# Name: Alice, Salary: 50000
# Company: TechCorp
# Name: Bob, Salary: 60000
# Company: TechCorp
#
# Total Employees: 2
# Company (via class): TechCorp
# Company (via object): TechCorp
