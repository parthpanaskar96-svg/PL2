# %% [markdown]
# <a href="https://colab.research.google.com/github/parthpanaskar96-svg/PL2/blob/main/Function_fibonacci_series_recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PYTHON

# %%
# Generate Fibonacci series using recursion
def fibonacci(n):
    if n <= 0:
        return 0              # Base case
    if n == 1:
        return 1              # Base case
    return fibonacci(n - 1) + fibonacci(n - 2)  # Recursive call

# Print Fibonacci series up to n terms
n = int(input('Enter number of terms: '))
print(f'Fibonacci series ({n} terms):')
for i in range(n):
    print(fibonacci(i), end=' ')
print()
# Out:
# Enter number of terms: 9
# Fibonacci series (9 terms):
# 0 1 1 2 3 5 8 13 21
