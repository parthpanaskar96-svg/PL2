# %% [markdown]
# <a href="https://colab.research.google.com/github/parthpanaskar96-svg/PL2/blob/main/Dict_student_detail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PYTHON

# %%
student = {
    'name': 'Student39',
    'roll_no': 24151565,
    'branch': 'Information Technology',
    'marks': 92.5,
    'email': 'student39@gmail.com'
}

print('Student Details:')
print('Name    :', student['name'])
print('Roll No :', student['roll_no'])
print('Branch  :', student['branch'])
print('Marks   :', student['marks'])
print('Email   :', student['email'])
# Out:
# Student Details:
# Name    : Student39
# Roll No : 24151565
# Branch  : Information Technology
# Marks   : 92.5
# Email   : student39@gmail.com
