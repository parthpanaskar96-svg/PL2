# %% [markdown]
# <a href="https://colab.research.google.com/github/parthpanaskar96-svg/PL2/blob/main/Topper_finder%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PYTHON

# %%
# Find student with highest marks
students = {
    'Shree': 88,
    'Parth'  : 95,
    'Dishant': 91,
    'Aditya' : 78,
    'Ranjit'  : 95
}

max_marks = max(students.values())
toppers = [name for name, marks in students.items() if marks == max_marks]

print('All Students:')
for name, marks in students.items():
    print(f'  {name}: {marks}')

print(f'\nHighest Marks: {max_marks}')
print(f'Topper(s)    : {", ".join(toppers)}')
# Out:
# All Students:
#   Shree: 88
#   Parth: 95
#   Dishant: 91
#   Aditya: 78
#   Ranjit: 95
#
# Highest Marks: 95
# Topper(s)    : Parth, Ranjit
